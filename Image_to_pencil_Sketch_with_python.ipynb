# %% [markdown]
# ##libraries openCV

# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread("/content/demo-image.jpg")
cv2_imshow(img)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=375x500 at 0x7F431CFFB070>
# -1

# %%
grayImage = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(grayImage)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=375x500 at 0x7F431CFFB9A0>
# -1

# %%
invertedImage = 255 - grayImage
cv2_imshow(invertedImage)
cv2.waitKey()
# Out:
# <PIL.Image.Image image mode=L size=375x500 at 0x7F431CFEABE0>
# -1

# %%
blurred = cv2.GaussianBlur(invertedImage, (21, 21), 0)

# %% [markdown]
# ##pencil sketch

# %%
invertedBlurred = 255 - blurred
pencil_sketch = cv2.divide(grayImage, invertedBlurred, scale=256.0)
cv2_imshow(pencil_sketch)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=375x500 at 0x7F431CFFB340>
# -1
